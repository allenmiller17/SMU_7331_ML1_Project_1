# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
# 1- Import dataset
pdata = pd.read_csv("airbnb.csv")

# %%
# Remove some extra columns
#pdata = pdata.drop(['id','price','number_of_reviews','latitude','longitude','review_scores_rating'], axis=1)
pcaData = pdata.drop(['id','property_type','room_type','bed_type','cancellation_policy','cleaning_fee','city','description','first_review','host_has_profile_pic','host_identity_verified','host_response_rate','host_since','instant_bookable','last_review','neighbourhood','zipcode'], axis=1)

# %%
pdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      74111 non-null  int64
#  1   log_price               74111 non-null  float64
#  2   property_type           74111 non-null  object
#  3   room_type               74111 non-null  object
#  4   accommodates            74111 non-null  int64
#  5   bathrooms               73911 non-null  float64
#  6   bed_type                74111 non-null  object
#  7   cancellation_policy     74111 non-null  object
#  8   cleaning_fee            74111 non-null  bool
#  9   city                    74111 non-null  object
#  10  description             74111 non-null  object
#  11  first_review            58247 non-null  object
#  12  host_has_profile_pic    73923 non-null  object
#  13  host_identity_verified  73923 non-null  object
#  14  host_response_rate      55812 non-null  object
#  15  host_since              73923 non-null  object
#  16  instant_bookable        74111 non-null  object
#  17  last_review             58284 non-null  object
#  18  latitude                74111 non-null  float64
#  19  longitude               74111 non-null  float64
#  20  neighbourhood           67239 non-null  object
#  21  number_of_reviews       74111 non-null  int64
#  22  review_scores_rating    57389 non-null  float64
#  23  zipcode                 73145 non-null  object
#  24  bedrooms                74020 non-null  float64
#  25  beds                    73980 non-null  float64
# dtypes: bool(1), float64(7), int64(3), object(15)
# memory usage: 14.2+ MB

# %%
pdata.skew()
# Out:
# id                     -0.260616
# log_price               0.514695
# accommodates            2.231561
# bathrooms               3.691453
# cleaning_fee           -1.059603
# latitude               -0.534766
# longitude              -0.407100
# number_of_reviews       3.702835
# review_scores_rating   -3.380861
# bedrooms                1.989849
# beds                    3.358000
# dtype: float64

# %%
pdata.head()

# %%
pdata.describe()

# %%
pdata.nunique()

# %%
#Looking at the distribution of Room Type
plt.figure(figsize=(5,5))
sns.countplot(pdata['room_type'])
plt.xticks(rotation=90)
plt.show()

# %%
#Looking at the distribution of City
plt.figure(figsize=(5,5))
sns.countplot(pdata['city'])
plt.xticks(rotation=90)
plt.show()

# %%
#Looking at the distribution of the entire list of property types
plt.figure(figsize=(5,5))
sns.countplot(pdata['property_type'])
plt.xticks(rotation=90)
plt.show()

# %%
#value_list = ["Apartment","House","Condominium","Loft","Townhouse"]
value_list = ["Apartment","House"]
boolean_series = ~pdata.property_type.isin(value_list)
filtered_df = pdata[boolean_series]

filtered_df.head(100)

for i in list (filtered_df.index):
    pdata.loc[i,'property_type'] = "other"

# %%
#Looking at the distribution of consolidated property type
plt.figure(figsize=(5,5))
sns.countplot(pdata['property_type'])
plt.xticks(rotation=90)
plt.show()

# %%
pdata = pdata.fillna(pdata.median())

# %%
pdata['price'] = np.exp(pdata.log_price)

# %%
pdata['log_reviews'] = np.log(pdata.review_scores_rating)

# %%
pdata.groupby(['city'])['review_scores_rating'].mean()
# Out:
# city
# Boston     94.046424
# Chicago    95.226136
# DC         95.154712
# LA         94.703158
# NYC        94.070852
# SF         95.234224
# Name: review_scores_rating, dtype: float64

# %%
pdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      74111 non-null  int64
#  1   log_price               74111 non-null  float64
#  2   property_type           74111 non-null  object
#  3   room_type               74111 non-null  object
#  4   accommodates            74111 non-null  int64
#  5   bathrooms               74111 non-null  float64
#  6   bed_type                74111 non-null  object
#  7   cancellation_policy     74111 non-null  object
#  8   cleaning_fee            74111 non-null  bool
#  9   city                    74111 non-null  object
#  10  description             74111 non-null  object
#  11  first_review            58247 non-null  object
#  12  host_has_profile_pic    73923 non-null  object
#  13  host_identity_verified  73923 non-null  object
#  14  host_response_rate      55812 non-null  object
#  15  host_since              73923 non-null  object
#  16  instant_bookable        74111 non-null  object
#  17  last_review             58284 non-null  object
#  18  latitude                74111 non-null  float64
#  19  longitude               74111 non-null  float64
#  20  neighbourhood           67239 non-null  object
#  21  number_of_reviews       74111 non-null  int64
#  22  review_scores_rating    74111 non-null  float64
#  23  zipcode                 73145 non-null  object
#  24  bedrooms                74111 non-null  float64
#  25  beds                    74111 non-null  float64
#  26  price                   74111 non-null  float64
#  27  log_reviews             74111 non-null  float64
# dtypes: bool(1), float64(9), int64(3), object(15)
# memory usage: 15.3+ MB

# %%
z = pdata[pdata['review_scores_rating']< 80]
for i in list (z[z['review_scores_rating']< 80].index):
    pdata.loc[i,'review_scores_rating'] = 80

z = pdata[pdata['price']> 200]
for i in list (z[z['price']> 200].index):
    pdata.loc[i,'price'] = 200

# %%
z = pdata[pdata['review_scores_rating'].isnull()]
for i in list (z[z['review_scores_rating']< 80].index):
    pdata.loc[i,'review_scores_rating'] = 80


marketing_train.loc[marketing_train.loc[:,i].isnull(),i]=marketing_train.loc[:,i].mean()
instead of mean, use median

# %%
z = pdata[pdata['review_scores_rating'].isnull()]

# %%
#Calculate the top whisker of the AgeDays to replace outliers with this value
IQRLV = np.percentile(pdata['price'], 25)
IQRHV = np.percentile(pdata['price'], 75)
OUTLIER = np.percentile(pdata['price'], 98)
ReplacePrice = (IQRHV - IQRLV) * 1.5
print(OUTLIER)


z = pdata[pdata['price']> ReplacePrice]
for i in list (z[z['price']> ReplacePrice].index):
    pdata.loc[i,'price'] = OUTLIER

# %%
np.percentile(pdata['price'], 98)

# %%
plt.figure(figsize=(5,5))
# distplot for continous columns
for i in ['price','log_price','review_scores_rating','log_reviews']:
    sns.boxplot(pdata[i])
    plt.show()

# %%
#Looking at tails and distributions of the following continuous values
for i in ['log_price','price','review_scores_rating','log_reviews']:
    sns.distplot(pdata[i])
    plt.show()

# %%
sns.jointplot(pdata['price'],pdata['review_scores_rating']);

# %%
pdata.boxplot(rot=90)

# %%
pdata.groupby(['room_type']).median().transpose()

# %%
sns.jointplot(pdata['price'],pdata['review_scores_rating'],kind='kde');

# %%
mydata = pdata.iloc[:, 1:27]
plt.figure(figsize=(9,9))
sns.heatmap(mydata.corr(), annot=True, linewidths=.5, fmt= '.1f', center = 1 )  # heatmap
plt.show()

# %%
sns.pairplot(pdata[['accommodates','review_scores_rating']])

# %%
pdata.nunique()

# %%
#sns.pairplot(pca)

sns.pairplot(pdata)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

def plot_pca(X):
    pca = PCA(n_components=X.shape[1])
    pcaData.fit(X)
    
    plt.subplots(figsize=(8,8))
    plt.plot(np.cumsum(pca.explained_variance_ratio_))
    plt.xlabel('number of components')
    plt.ylabel('cumlative explained variance')
    print ('Cumulative Explained variance at 200 components:', sum(pca.explained_variance_ratio_[0:199]))
    
plot_pca(pcaData)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-2350a3cbc88f> in <module>
#      12     print ('Cumulative Explained variance at 200 components:', sum(pca.explained_variance_ratio_[0:199]))
#      13
# ---> 14 plot_pca(pcaData)
#
# <ipython-input-29-2350a3cbc88f> in plot_pca(X)
#       4 def plot_pca(X):
#       5     pca = PCA(n_components=X.shape[1])
# ----> 6     pcaData.fit(X)
#       7
#       8     plt.subplots(figsize=(8,8))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'fit'

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

def plot_pca(X):
    pca = PCA(n_components=X.shape[1])
    pca.fit(X)
